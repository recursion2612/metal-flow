# %% [markdown]
# # DOES WORK
# - Only epr does not run because it needs to be updated to 1.0.1. {17-07-2026}
# - plot_convergence() gives a figure inline and also plots it on Ansys window. This causes the focus to shift from the design window to new plot window. Therefore when plot_fields() + save_scrrenshot() are called next the focus is not on the design and the fields are not plotted on the design. On the other hand, the project is updated with fileds but the scrrenshot does not show them, we get screenshot of design only. {17-07-2026}

# %% [markdown]
# # 4.12 Analyzing and tuning a resonator
# We will use here the `advanced` EPR method to run the simulation and analysi, which directly controls renderers and external packages. Please refer to the tutorial notebook 4.2 to follow the `suggested` flow to run the analysis.

# %% [markdown]
# ## Resonator design
# 1. Prepare the single transmon qubit layout in qiskit-metal. <br>
#
# ## Resonator analysis using EPR method
# 1. Set-up and run a finite element simulate to extract the eigenmode. <br>
# 1. Display EM fields to inspect quality of the setup. <br>
# 1. Calculate EPR of substrate.  <br>

# %% [markdown]
# ## Prerequisite
# You need to have a working local installation of Ansys.<br>
# Also you will need the following directives and inports.

# %% [markdown]
# ## 1. Create the Resonator design
#
# Fix the design dimensions that you intend to reflect in the design rendering. <br>
# Note that the design size extends from the origin into the first quadrant.

# %%
from qiskit_metal import designs, Dict, view
design = designs.DesignPlanar({}, True)
design.chips.main.size["size_x"] = "2mm"
design.chips.main.size["size_y"] = "2mm"

# gui = MetalGUI(design)

# %% [markdown]
# Create a readout resonator. Here, we define one end of the resonator as a short and the other end as an open.

# %%
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.terminations.short_to_ground import ShortToGround

design.delete_all_components()

otg = OpenToGround(
    design, "open_to_ground", options=dict(pos_x="1.25mm", pos_y="0um", orientation="0")
)
stg = ShortToGround(
    design,
    "short_to_ground",
    options=dict(pos_x="-1.25mm", pos_y="0um", orientation="180"),
)
rt_meander = RouteMeander(
    design,
    "readout",
    Dict(
        total_length="6 mm",
        hfss_wire_bonds=True,
        fillet="90 um",
        lead=dict(start_straight="100um"),
        pin_inputs=Dict(
            start_pin=Dict(component="short_to_ground", pin="short"),
            end_pin=Dict(component="open_to_ground", pin="open"),
        ),
    ),
)

# gui.rebuild()
# gui.autoscale()
view(design)

# %% [markdown]
# ## 2. Analyze the resonator using the Eigenmode-EPR method
#
# In this section we will use a semi-manual (advanced) analysis flow. Please refer to tutorial 4.2 for the `suggested` method. As illustrated, the methods are equivalent, but the advanced method allows you to directly override some renderer-specific settings.
#
# ### Finite Element Eigenmode Analysis
#
# #### Setup
#
# Select the analysis you intend to run from the `qiskit_metal.analyses` collection.<br>
# Select the design to analyze and the tool to use for any external simulation.

# %%
from qiskit_metal.analyses.quantization import EPRanalysis

eig_res = EPRanalysis(design, "hfss")

# %% [markdown]
# For the Eigenmode simulation portion, you can either:
# 1. Use the `eig_res` user-friendly methods (see tutorial 4.2)
# 2. Control directly the simulation tool from the tool's GUI (outside metal - see specific vendor instructions)
# 3. Use the renderer methods
# In this section we show the advanced method (method 3).
#
# The renderer can be reached from the analysis class. Let's give it a shorter alias.

# %%
hfss = eig_res.sim.renderer

# %% [markdown]
# Now we connect to the tool using the unified command.

# %%
hfss.start()
# Out:
# INFO 11:56AM [connect_project]: Connecting to Ansys Desktop API...
# INFO 11:56AM [load_ansys_project]: 	Opened Ansys App
# INFO 11:56AM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.4
# INFO 11:56AM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/DELL/Documents/Ansoft/
# 	Project:   Project283
# INFO 11:56AM [connect_design]: No active design found (or error getting active design).
# INFO 11:56AM [connect]: 	 Connected to project "Project283". No design detected
# True

# %% [markdown]
# The previous command is supposed to open ansys (if closed), create a new project and finally connect this notebook to it.
#
# If for any reason the previous cell failed, please try the manual path described in the next three cells:
# 1. uncomment and execute only **one** of the lines in the first cell.
# 1. uncomment and execute the second cell.
# 1. uncomment and execute only **one** of the lines in the third cell.

# %%
# hfss.open_ansys()   # this opens Ansys 2021 R2 if present
# hfss.open_ansys(path_var='ANSYSEM_ROOT251')
# hfss.open_ansys(path='C:\Program Files\AnsysEM\AnsysEM21.1\Win64')
# hfss.open_ansys(path='../../../Program Files/AnsysEM/AnsysEM21.1/Win64')

# %%
# hfss.new_ansys_project()

# %%
# hfss.connect_ansys()
# hfss.connect_ansys('C:\\project_path\\', 'Project1')  # will open a saved project before linking the Jupyter session

# %% [markdown]
# #### Execute simulation and verify convergence
#
# Create and activate an eigenmode design called "Readout".

# %%
hfss.activate_ansys_design(
    "Readout", "eigenmode"
)  # use new_ansys_design() to force creation of a blank design
# Out:
# 11:56AM 03s WARNING [activate_ansys_design]: The design_name=Readout was not in active project.  Designs in active project are:
# [].  A new design will be added to the project.
# INFO 11:56AM [connect_design]: 	Opened active design
# 	Design:    Readout [Solution type: Eigenmode]
# WARNING 11:56AM [connect_setup]: 	No design setup detected.
# WARNING 11:56AM [connect_setup]: 	Creating eigenmode default setup.
# INFO 11:56AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)

# %% [markdown]
# Render the resonator called readout in Metal, to "Readout" design in Ansys.

# %%
hfss.render_design(["short_to_ground", "readout", "open_to_ground"], [])
# hfss.save_screenshot()

# %% [markdown]
# Set the convergence parameters and junction properties in the Ansys design. <br>
# Then run the analysis and plot the convergence.

# %%
# Analysis properties
setup = hfss.pinfo.setup
setup.passes = 20
print(f"""
Number of eigenmodes to find             = {setup.n_modes}
Number of simulation passes              = {setup.passes}
Convergence freq max delta percent diff  = {setup.delta_f}
""")

# Next 2 lines are counterinuitive, since there is no junction in this resonator.
# However, these are necessary to make pyEPR work correctly. Please do note delete
hfss.pinfo.design.set_variable("Lj", "10 nH")
hfss.pinfo.design.set_variable("Cj", "0 fF")

setup.analyze()
# Out:
# INFO 11:56AM [analyze]: Analyzing setup Setup
# Number of eigenmodes to find             = 1
# Number of simulation passes              = 20
# Convergence freq max delta percent diff  = 0.1
# 0

# %% [markdown]
# To plot the results you can use the `plot_convergences()` method from the `eig_res.sim` object. The method will read the data from the variables local to the `eig_res.sim` object, so we first need to assign the simulation results to these two variables. let's do both (assignment and plotting) in the next cell.
#
# Note: if `hfss.get_convergences()` raises a com_error, it is likely due to the simulation not converging. Try increasing the number of passess in the setup above or tweak other simulation or layout parameters.

# %%
eig_res.sim.convergence_t, eig_res.sim.convergence_f, _ = hfss.get_convergences()
eig_res.sim.plot_convergences()
# Out:
# 11:58AM 24s INFO [get_f_convergence]: Saved convergences to c:\Users\DELL\chip-design\metal-flow\tutorials\4 Analysis\B. Advanced - Direct use of the renderers\hfss_eig_f_convergence.csv

# %% [markdown]
# #### Refine the resonator design, rerun simulation and verify convergence
#
# Next, we change the length of the resonator and see how the eigen frequency changes.

# %%
rt_meander.options.total_length = "9 mm"

# gui.rebuild()
# gui.autoscale()

# %% [markdown]
# Need to render the updated design again. Let's do that in a new design ("Readout_1") to avoid conflicts. Alternatively you will need to delete all the shapes from the previous design to be able to re-draw in it.

# %%
hfss.activate_ansys_design(
    "Readout_1", "eigenmode"
)  # use new_ansys_design() to force creation of a blank design
# Out:
# 11:58AM 25s WARNING [activate_ansys_design]: The design_name=Readout_1 was not in active project.  Designs in active project are:
# ['Readout'].  A new design will be added to the project.
# INFO 11:58AM [connect_design]: 	Opened active design
# 	Design:    Readout_1 [Solution type: Eigenmode]
# WARNING 11:58AM [connect_setup]: 	No design setup detected.
# WARNING 11:58AM [connect_setup]: 	Creating eigenmode default setup.
# INFO 11:58AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)

# %%
hfss.render_design(["short_to_ground", "readout", "open_to_ground"], [])
# hfss.save_screenshot()

# %% [markdown]
# now re-execute the analysis. We will skip the design variable setup since they are still in memory.

# %%
# Analysis properties
setup = hfss.pinfo.setup
setup.passes = 20
print(f"""
Number of eigenmodes to find             = {setup.n_modes}
Number of simulation passes              = {setup.passes}
Convergence freq max delta percent diff  = {setup.delta_f}
""")

# Next 2 lines are counterinuitive, since there is no junction in this resonator.
# However, these are necessary to make pyEPR work correctly. Please do note delete
hfss.pinfo.design.set_variable("Lj", "10 nH")
hfss.pinfo.design.set_variable("Cj", "0 fF")

setup.analyze()
# Out:
# INFO 11:58AM [analyze]: Analyzing setup Setup
# Number of eigenmodes to find             = 1
# Number of simulation passes              = 20
# Convergence freq max delta percent diff  = 0.1
# 0

# %%
eig_res.sim.convergence_t, eig_res.sim.convergence_f, _ = hfss.get_convergences()
eig_res.sim.plot_convergences()
# Out:
# 12:00PM 43s INFO [get_f_convergence]: Saved convergences to c:\Users\DELL\chip-design\metal-flow\tutorials\4 Analysis\B. Advanced - Direct use of the renderers\hfss_eig_f_convergence.csv

# %% [markdown]
# From the above analyses we observe that for a total length of 6 mm for the resonator, the Eigen Frequency was close to 4.9 GHz. However, for a total length of 9 mm, this frequency is close to 3.3 GHz. Similar analysis can be performed by the user for matching a particular frequency of interest.

# %% [markdown]
# #### Plot the EM field for inspection
# Display the Ansys modeler window and plot the E-field on the chip's surface.

# %%
hfss.modeler._modeler.ShowWindow()
hfss.plot_ansys_fields("main")
# Out:
# 12:00PM 44s WARNING [plot_ansys_fields]: This method is deprecated. Change your scripts to use plot_fields()

# %%
# hfss.save_screenshot()

# %% [markdown]
# Delete the newly created E-field plot to prepare for the next phase.

# %%
hfss.plot_ansys_delete(["Mag_E1"])
# Out:
# 12:00PM 44s WARNING [plot_ansys_delete]: This method is deprecated. Change your scripts to use clear_fields()

# %% [markdown]
# ### EPR Analysis
# In the `suggested` (tutorial 4.2) flow, we would now prepare the setup using `eig_res.setup` and run the analysis with `eig_res.run_epr()`. Notice that this method requires previous set of the `eig_res` variables `convergence_t` and `convergence_f` like we did a thee cells earlier.
#
# However we here exemplify the advanced approach, which is Ansys-specific since it uses the pyEPR module methods directly.
# #### Execute the energy distribution analysis
#
# First initialize epr for non-junction analysis. This will set the ground plain to 'main'.

# %%
eig_res.epr_start(no_junctions=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 eig_res.epr_start(no_junctions=True)
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:202, in EPRanalysis.epr_start(self, no_junctions)
#     198 system["junctions"] = (
#     199     {} if no_junctions else {k: dict(v) for (k, v) in s.junctions.items()}
#     200 )
#     201 system["dissipatives"] = dict(s.dissipatives)
# --> 202 self.sim.renderer.epr_start(**system)
#     203 return system
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:1800, in QAnsysRenderer.epr_start(self, junctions, dissipatives)
#    1797         self.pinfo.dissipative[k] = v
#    1799 # Class handling microwave analysis on eigenmode solutions
# -> 1800 self.epr_distributed_analysis = epr.DistributedAnalysis(self.pinfo)
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:171, in DistributedAnalysis.__init__(self, *args, **kwargs)
#     167 self._hfss_variables = Dict()
#     169 self._previously_analyzed = set()  # previously analyzed variations
# --> 171 self.update_ansys_info()
#     173 logger.info('Design "%s" info:', self.design.name)
#     174 logger.info(
#     175     "\t%-15s %d\n\t%-15s %d",
#     176     "# eigenmodes", self.n_modes, "# variations", self.n_variations,
#     177 )
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:507, in DistributedAnalysis.update_ansys_info(self)
#     504     else:
#     505         self.n_modes = 0
# --> 507 self._update_ansys_variables()
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:516, in DistributedAnalysis._update_ansys_variables(self, variations)
#     513 variations = variations or self.variations
#     514 for variation in variations:
#     515     self._hfss_variables[variation] = pd.Series(
# --> 516         self.get_variables(variation=variation)
#     517     )
#     518 return self._hfss_variables
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:542, in DistributedAnalysis.get_variables(self, variation)
#     534 def get_variables(self, variation=None):
#     535     """
#     536     Get ansys variables.
#     537
#    (...)    540             such as '0', '1', ...
#     541     """
# --> 542     lv = self._get_lv(variation)
#     543     variables = OrderedDict()
#     544     for ii in range(int(len(lv) / 2)):
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:370, in DistributedAnalysis._get_lv(self, variation)
#     368     lv = self._parse_listvariations(lv)
#     369 else:
# --> 370     lv = self._list_variations[ureg(variation)]
#     371     lv = self._parse_listvariations(lv)
#     372 return lv
#
# TypeError: tuple indices must be integers or slices, not Quantity

# %% [markdown]
# Execute microwave analysis on eigenmode solutions.

# %%
eprd = hfss.epr_distributed_analysis

# %% [markdown]
# Find the electric and magnetic energy stored in the substrate and the system.

# %%
ℰ_elec = eprd.calc_energy_electric()
ℰ_elec_substrate = eprd.calc_energy_electric(None, "main")
ℰ_mag = eprd.calc_energy_magnetic()

print(f"""
ℰ_elec_all       = {ℰ_elec}
ℰ_elec_substrate = {ℰ_elec_substrate}
EPR of substrate = {ℰ_elec_substrate / ℰ_elec * 100:.1f}%

ℰ_mag    = {ℰ_mag}
""")

# %% [markdown]
# Release Ansys session

# %%
eig_res.sim.close()

# %% [markdown]
# (optional) close the GUI.

# %%
# gui.main_window.close()
