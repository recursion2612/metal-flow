# %% [markdown]
# # 4.02 Eigenmode and EPR analysis
# ## Prerequisite
# You need to have a working local installation of Ansys.

# %% [markdown]
# ## Sections
# ### I. Transmon only
# 1. Prepare the layout in qiskit-metal. <br>
# 1. Run finite element eigenmode analysis. <br>
# 1. Plot fields and display them. <br>
# 1. Set up EPR junction dictionary. <br>
# 1. Run EPR analysis on single mode. <br>
# 1. Get qubit freq and anharmonicity. <br>
# 1. Calculate EPR of substrate.  <br>
# 1. (Extra: Calculate surface EPR.) <br>
#
# ### II. Resonator only
# 1. Update the layout in qiskit-metal. <br>
# 1. Run finite element eigenmode analysis. <br>
# 1. Plot fields and display them. <br>
# 1. Calculate EPR of substrate. <br>
#
# ### III. Transmon & resonator
# 1. Update the layout in qiskit-metal. <br>
# 1. Run finite element eigenmode analysis. <br>
# 1. Plot fields and display them. <br>
# 1. Set up EPR junction dictionary. <br>
# 1. Run EPR analysis on the two modes. <br>
# 1. Get qubit frequency and anharmonicity. <br>
#
# ### IV. Analyze a coupled 2 transmon system.
# 1. Finite Element Eigenmode Analysis
# 1. Identify the mode you want. The mode can inclusively be from 1 to setup.n_modes.
# 1. Set variables in the Ansys design. As before, we seek 2 modes.
# 1. Set up the simulation and specify the variables for the sweep.
# 1. Plot the E-field on the chip's surface.
# 1. Specify the junctions in the model; in this case there are 2 junctions.
# 1. Find the electric and magnetic energy stored in the substrate and the system as a whole.
# 1. Perform EPR analysis for all modes and variations.

# %% [markdown]
# ## 1. Analyze the transmon qubit by itself
#
# We will use the analysis package - applicable to most users. Advanced users might want to expand the package, or directly interact with the renderer. The renderer is one of the properties of the analysis class.
#
# ### Create the Qbit design
#
# Setup a design of a given dimension. Dimensions will be respected in the design rendering. <br>
# Note that the design size extends from the origin into the first quadrant.

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw, MetalGUI
from qiskit_metal import Dict, Headings

# %%
design = designs.DesignPlanar({}, True)
design.chips.main.size["size_x"] = "2mm"
design.chips.main.size["size_y"] = "2mm"

gui = MetalGUI(design)

# %% [markdown]
# Create a single transmon with one readout resonator and move it to the center of the chip previously defined.

# %%
from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket

design.delete_all_components()

q1 = TransmonPocket(
    design,
    "Q1",
    options=dict(
        pad_width="425 um",
        pocket_height="650um",
        connection_pads=dict(readout=dict(loc_W=+1, loc_H=+1, pad_width="200um")),
    ),
)

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ### Finite Element Eigenmode Analysis
#
# #### Setup
#
# Select the analysis you intend to run from the `qiskit_metal.analyses` collection.<br>
# Select the design to analyze and the tool to use for any external simulation.

# %%
from qiskit_metal.analyses.quantization import EPRanalysis

# %%
eig_qb = EPRanalysis(design, "hfss")

# %% [markdown]
# Review and update the convergence parameters and junction properties by executing following two cells. We exemplify three different methods to update the setup parameters.

# %%
eig_qb.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1,
#  'n_modes': 1,
#  'max_delta_f': 0.5,
#  'max_passes': 10,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '10 nH', 'Cj': '0 fF'}}

# %%
# example: update single setting
eig_qb.sim.setup.max_passes = 6
eig_qb.sim.setup.vars.Lj = "11 nH"
# example: update multiple settings
eig_qb.sim.setup_update(max_delta_f=0.4, min_freq_ghz=1.1)

eig_qb.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1.1,
#  'n_modes': 1,
#  'max_delta_f': 0.4,
#  'max_passes': 6,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '11 nH', 'Cj': '0 fF'}}

# %% [markdown]
# #### Execute simulation and verify convergence and EM field
# Analyze a single qubit with shorted terminations. Then observe the frequency convergence plot. If not converging, you might want to increase the min_passes value to force the renderer to increase accuracy.
#
# You can use the method `run()` instead of `sim.run()` in the following cell if you want to run both eigenmode and epr analysis in a single step. If so, make sure to also tweak the setup for the epr analysis. The input parameters are otherwise the same for the two methods.

# %%
eig_qb.sim.run(
    name="Qbit", components=["Q1"], open_terminations=[], box_plus_buffer=False
)
eig_qb.sim.plot_convergences()
# Out:
# INFO 12:25PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 12:25PM [load_ansys_project]: 	Opened Ansys App
# INFO 12:25PM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.4
# INFO 12:25PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/DELL/Documents/Ansoft/
# 	Project:   Project267
# INFO 12:25PM [connect_design]: 	Opened active design
# 	Design:    Design_q3d [Solution type: Q3D]
# INFO 12:25PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 12:25PM [connect]: 	Connected to project "Project267" and design "Design_q3d" 😀
#
# INFO 12:25PM [connect_design]: 	Opened active design
# 	Design:    Qbit_hfss [Solution type: Eigenmode]
# WARNING 12:25PM [connect_setup]: 	No design setup detected.
# WARNING 12:25PM [connect_setup]: 	Creating eigenmode default setup.
# INFO 12:25PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:25PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:25PM [analyze]: Analyzing setup Setup
# 12:26PM 03s INFO [get_f_convergence]: Saved convergences to c:\Users\DELL\chip-design\metal-flow\tutorials\4 Analysis\A. Core - EM and quantization\hfss_eig_f_convergence.csv

# %% [markdown]
# The last variables you pass to the `run()` or `sim.run()` methods, will be stored in the `sim.setup` dictionary under the key `run`. You can recall the information passed by either accessing the dictionary directly, or by using the print handle below.

# %%
# eig_qb.setup.run    <- direct access
eig_qb.sim.print_run_args()
# Out:
# This analysis object run with the following kwargs:
# {'name': 'Qbit', 'components': ['Q1'], 'open_terminations': [], 'port_list': None, 'jj_to_port': None, 'ignored_jjs': None, 'box_plus_buffer': False}

# %% [markdown]
# (optional) Captures the renderer GUI

# %%
eig_qb.sim.save_screenshot()
# Out:
# WindowsPath('c:/Users/DELL/chip-design/metal-flow/tutorials/4 Analysis/A. Core - EM and quantization/ansys.png')

# %% [markdown]
# (optional) Work directly with the convergence numbers

# %%
eig_qb.sim.convergence_f
# Out:
#          re(Mode(1)) [g]
# Pass []
# 1               3.161556
# 2               4.767850
# 3               5.756671
# 4               6.009428
# 5               6.131182
# 6               6.201098

# %% [markdown]
# (optional) You can re-run the analysis after varying the parameters.<br>
# Not passing the parameter `components` to the `sim.run()` method, skips the rendering and tries to run the analysis on the latest design. If a design is not found, the full metal design is rendered.

# %%
eig_qb.sim.setup.min_freq_ghz = 4
eig_qb.sim.run()
eig_qb.sim.convergence_f
# Out:
# INFO 12:26PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:26PM [analyze]: Analyzing setup Setup
# 12:26PM 35s INFO [get_f_convergence]: Saved convergences to c:\Users\DELL\chip-design\metal-flow\tutorials\4 Analysis\A. Core - EM and quantization\hfss_eig_f_convergence.csv
#          re(Mode(1)) [g]
# Pass []
# 1              41.108313
# 2               4.879058
# 3               5.504110
# 4               5.961907
# 5               6.108263
# 6               6.195272

# %% [markdown]
# Verify that the Electro(magnetic) fields look realistic.

# %%
eig_qb.sim.plot_fields(
    "main"
)  # TODO:::: Ez, normal component.....decide which field typically on the qbit, or on the crossing between meanders
eig_qb.sim.save_screenshot()
# Out:
# INFO 12:26PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# WindowsPath('c:/Users/DELL/chip-design/metal-flow/tutorials/4 Analysis/A. Core - EM and quantization/ansys.png')

# %% [markdown]
# (optional) clear the renderer by removing the fields

# %%
eig_qb.sim.clear_fields()

# %% [markdown]
# ### EPR Analysis
# #### Setup
# Identify the non-linear (Josephson) junctions in the model. You will need to list the junctions in the epr setup.
#
# In this case there's only one junction, namely 'jj'. Let's see what we need to change in the default setup.

# %%
eig_qb.setup
# Out:
# {'junctions': {'jj': {'Lj_variable': 'Lj',
#    'Cj_variable': 'Cj',
#    'rect': '',
#    'line': ''}},
#  'dissipatives': {'dielectrics_bulk': ['main']},
#  'cos_trunc': 8,
#  'fock_trunc': 7,
#  'sweep_variable': 'Lj'}

# %% [markdown]
# The name of the `Lj_variable` and `Cj_variable` match with our model. However it is missing the names of the shapes that identify the junction (`rect` and `line`). Look for those in the renderer and find the name. Then let's change the name (See below).

# %%
eig_qb.setup.junctions.jj.rect = "JJ_rect_Lj_Q1_rect_jj"
eig_qb.setup.junctions.jj.line = "JJ_Lj_Q1_rect_jj_"
eig_qb.setup
# Out:
# {'junctions': {'jj': {'Lj_variable': 'Lj',
#    'Cj_variable': 'Cj',
#    'rect': 'JJ_rect_Lj_Q1_rect_jj',
#    'line': 'JJ_Lj_Q1_rect_jj_'}},
#  'dissipatives': {'dielectrics_bulk': ['main']},
#  'cos_trunc': 8,
#  'fock_trunc': 7,
#  'sweep_variable': 'Lj'}

# %% [markdown]
# We will now run epr as a single step. On screen you will observe various information in this order:
# * stored energy = Electric and magnetic energy stored in the substrate and the system as a whole.
# * EPR analysis results for all modes/variations.
# * Spectrum analysis.
# * Hamiltonian report.

# %%
eig_qb.run_epr()

#### equivalent individual calls
# s = self.setup
# self.epr_start()
# eig_qb.get_stored_energy()
# eig_qb.run_analysis()
# eig_qb.spectrum_analysis(s.cos_trunc, s.fock_trunc)
# eig_qb.report_hamiltonian(s.swp_variable)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 eig_qb.run_epr()
#       2
#       3 #### equivalent individual calls
#       4 # s = self.setup
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:176, in EPRanalysis.run_epr(self, no_junctions)
#     173 # wipe data from the previous run (if any)
#     174 self.clear_data()
# --> 176 self.get_stored_energy(no_junctions)
#     177 if not no_junctions:
#     178     self.run_analysis()
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:209, in EPRanalysis.get_stored_energy(self, no_junctions)
#     206 """Calculate the energy stored in the system based on the eigenmode results."""
#     207 # execute EPR and energy extraction
#     208 self.energy_elec, self.energy_elec_sub, self.energy_mag = (
# --> 209     self.sim.renderer.epr_get_stored_energy(**self.epr_start(no_junctions))
#     210 )
#     212 # present a human-friendly output
#     213 print(f"""
#     214 energy_elec_all       = {self.energy_elec}
#     215 energy_elec_substrate = {self.energy_elec_sub}
#    (...)    219 energy_mag % of energy_elec_all  = {self.energy_mag / self.energy_elec * 100:.1f}%
#     220 """)
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:202, in EPRanalysis.epr_start(self, no_junctions)
#     198 system["junctions"] = (
#     199     {} if no_junctions else {k: dict(v) for (k, v) in s.junctions.items()}
#     200 )
#     201 system["dissipatives"] = dict(s.dissipatives)
# --> 202 self.sim.renderer.epr_start(**system)
#     203 return system
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:1800, in QAnsysRenderer.epr_start(self, junctions, dissipatives)
#    1797         self.pinfo.dissipative[k] = v
#    1799 # Class handling microwave analysis on eigenmode solutions
# -> 1800 self.epr_distributed_analysis = epr.DistributedAnalysis(self.pinfo)
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:171, in DistributedAnalysis.__init__(self, *args, **kwargs)
#     167 self._hfss_variables = Dict()
#     169 self._previously_analyzed = set()  # previously analyzed variations
# --> 171 self.update_ansys_info()
#     173 logger.info('Design "%s" info:', self.design.name)
#     174 logger.info(
#     175     "\t%-15s %d\n\t%-15s %d",
#     176     "# eigenmodes", self.n_modes, "# variations", self.n_variations,
#     177 )
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:507, in DistributedAnalysis.update_ansys_info(self)
#     504     else:
#     505         self.n_modes = 0
# --> 507 self._update_ansys_variables()
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:516, in DistributedAnalysis._update_ansys_variables(self, variations)
#     513 variations = variations or self.variations
#     514 for variation in variations:
#     515     self._hfss_variables[variation] = pd.Series(
# --> 516         self.get_variables(variation=variation)
#     517     )
#     518 return self._hfss_variables
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:542, in DistributedAnalysis.get_variables(self, variation)
#     534 def get_variables(self, variation=None):
#     535     """
#     536     Get ansys variables.
#     537
#    (...)    540             such as '0', '1', ...
#     541     """
# --> 542     lv = self._get_lv(variation)
#     543     variables = OrderedDict()
#     544     for ii in range(int(len(lv) / 2)):
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:370, in DistributedAnalysis._get_lv(self, variation)
#     368     lv = self._parse_listvariations(lv)
#     369 else:
# --> 370     lv = self._list_variations[ureg(variation)]
#     371     lv = self._parse_listvariations(lv)
#     372 return lv
#
# TypeError: tuple indices must be integers or slices, not Quantity

# %% [markdown]
# ## 2. Analyze the CPW resonator by itself
# ### Update the design in Metal
# Connect the transmon to a CPW. <br>
# The other end of the CPW connects to an open to ground termination.

# %%
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander

otg = OpenToGround(
    design, "open_to_ground", options=dict(pos_x="1.75mm", pos_y="0um", orientation="0")
)
RouteMeander(
    design,
    "readout",
    Dict(
        total_length="6 mm",
        hfss_wire_bonds=True,
        fillet="90 um",
        lead=dict(start_straight="100um"),
        pin_inputs=Dict(
            start_pin=Dict(component="Q1", pin="readout"),
            end_pin=Dict(component="open_to_ground", pin="open"),
        ),
    ),
)

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ### Finite Element Eigenmode Analysis
#
# #### Setup
#
# Create a separate analysis object, dedicated to the readout. This allows to retain the Qubit session active, in case we will later need to tweak the design and repeat the simulation. When different renderers are available you could even consider using different more appopriate ones for each simulation steps of this notebook, but for now we will be using the same one.

# %%
eig_rd = EPRanalysis(design, "hfss")

# %% [markdown]
# For the resonator analysis we will use the default setup. Youn can feel free to edit it the same way we did in section 1.
#
# #### Execute simulation and verify convergence and EM field
# Analyze the readout in isolation. Select the readout and terminate it with an open on both ends. Note that we are selecting for this analysis both the `readout` component and the `open_to_ground` component. The `open_to_ground` component might feel redundant because we are specifying in that open in the `open_terminations`, and the end converging result is indeed the same. However the `open_to_ground` appears to help the system to converge faster, so we keep it in there.

# %%
eig_rd.sim.run(
    name="Readout",
    components=["readout", "open_to_ground"],
    open_terminations=[("readout", "start"), ("readout", "end")],
)
eig_rd.sim.plot_convergences()
# Out:
# INFO 12:26PM [connect_design]: 	Opened active design
# 	Design:    Readout_hfss [Solution type: Eigenmode]
# WARNING 12:26PM [connect_setup]: 	No design setup detected.
# WARNING 12:26PM [connect_setup]: 	Creating eigenmode default setup.
# INFO 12:26PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:26PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:26PM [analyze]: Analyzing setup Setup
# 12:28PM 19s INFO [get_f_convergence]: Saved convergences to c:\Users\DELL\chip-design\metal-flow\tutorials\4 Analysis\A. Core - EM and quantization\hfss_eig_f_convergence.csv

# %%
eig_rd.sim.save_screenshot()  # optional
# Out:
# WindowsPath('c:/Users/DELL/chip-design/metal-flow/tutorials/4 Analysis/A. Core - EM and quantization/ansys.png')

# %% [markdown]
# Recover eigenmode frequencies for each variation.

# %%
eig_rd.get_frequencies()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 eig_rd.get_frequencies()
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:244, in EPRanalysis.get_frequencies(self)
#     240 def get_frequencies(self):
#     241     """Short-cut to the same-name method found in renderers.ansys_renderer.py.
#     242     Eventually, the analysis code needs to be only here, and the renderer method deprecated.
#     243     """
# --> 244     system = self.epr_start(no_junctions=True)
#     245     return self.sim.renderer.epr_get_frequencies(**system)
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:202, in EPRanalysis.epr_start(self, no_junctions)
#     198 system["junctions"] = (
#     199     {} if no_junctions else {k: dict(v) for (k, v) in s.junctions.items()}
#     200 )
#     201 system["dissipatives"] = dict(s.dissipatives)
# --> 202 self.sim.renderer.epr_start(**system)
#     203 return system
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:1800, in QAnsysRenderer.epr_start(self, junctions, dissipatives)
#    1797         self.pinfo.dissipative[k] = v
#    1799 # Class handling microwave analysis on eigenmode solutions
# -> 1800 self.epr_distributed_analysis = epr.DistributedAnalysis(self.pinfo)
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:171, in DistributedAnalysis.__init__(self, *args, **kwargs)
#     167 self._hfss_variables = Dict()
#     169 self._previously_analyzed = set()  # previously analyzed variations
# --> 171 self.update_ansys_info()
#     173 logger.info('Design "%s" info:', self.design.name)
#     174 logger.info(
#     175     "\t%-15s %d\n\t%-15s %d",
#     176     "# eigenmodes", self.n_modes, "# variations", self.n_variations,
#     177 )
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:507, in DistributedAnalysis.update_ansys_info(self)
#     504     else:
#     505         self.n_modes = 0
# --> 507 self._update_ansys_variables()
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:516, in DistributedAnalysis._update_ansys_variables(self, variations)
#     513 variations = variations or self.variations
#     514 for variation in variations:
#     515     self._hfss_variables[variation] = pd.Series(
# --> 516         self.get_variables(variation=variation)
#     517     )
#     518 return self._hfss_variables
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:542, in DistributedAnalysis.get_variables(self, variation)
#     534 def get_variables(self, variation=None):
#     535     """
#     536     Get ansys variables.
#     537
#    (...)    540             such as '0', '1', ...
#     541     """
# --> 542     lv = self._get_lv(variation)
#     543     variables = OrderedDict()
#     544     for ii in range(int(len(lv) / 2)):
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:370, in DistributedAnalysis._get_lv(self, variation)
#     368     lv = self._parse_listvariations(lv)
#     369 else:
# --> 370     lv = self._list_variations[ureg(variation)]
#     371     lv = self._parse_listvariations(lv)
#     372 return lv
#
# TypeError: tuple indices must be integers or slices, not Quantity

# %% [markdown]
# Display the Ansys modeler window and plot the E-field on the chip's surface.

# %%
eig_rd.sim.plot_fields("main")
eig_rd.sim.save_screenshot()
# Out:
# INFO 12:40PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# WindowsPath('c:/Users/DELL/chip-design/metal-flow/tutorials/4 Analysis/A. Core - EM and quantization/ansys.png')

# %% [markdown]
# #### Refine
#
# If convergence is not complete, or the EM field is unclear, update the number of passes and re-run the flow (below repeated for convenience)

# %%
eig_rd.sim.setup.max_passes = 15  # update single setting
eig_rd.sim.run()
eig_rd.sim.plot_convergences()
# Out:
# INFO 12:40PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:40PM [analyze]: Analyzing setup Setup
# 12:42PM 31s INFO [get_f_convergence]: Saved convergences to c:\Users\DELL\chip-design\metal-flow\tutorials\4 Analysis\A. Core - EM and quantization\hfss_eig_f_convergence.csv

# %% [markdown]
# Display the Ansys modeler window again and plot the E-field on the chip's surface with this updated number of passes. <br>
# Note that the bright areas have become much smoother compared to the previous image, indicating better convergence.

# %%
eig_rd.sim.plot_fields("main")
# Out:
# INFO 12:43PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)

# %%
eig_rd.sim.save_screenshot()
# Out:
# WindowsPath('c:/Users/DELL/chip-design/metal-flow/tutorials/4 Analysis/A. Core - EM and quantization/ansys.png')

# %% [markdown]
# ### EPR Analysis
# Find the electric and magnetic energy stored in the readout system.

# %%
eig_rd.run_epr(no_junctions=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 eig_rd.run_epr(no_junctions=True)
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:176, in EPRanalysis.run_epr(self, no_junctions)
#     173 # wipe data from the previous run (if any)
#     174 self.clear_data()
# --> 176 self.get_stored_energy(no_junctions)
#     177 if not no_junctions:
#     178     self.run_analysis()
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:209, in EPRanalysis.get_stored_energy(self, no_junctions)
#     206 """Calculate the energy stored in the system based on the eigenmode results."""
#     207 # execute EPR and energy extraction
#     208 self.energy_elec, self.energy_elec_sub, self.energy_mag = (
# --> 209     self.sim.renderer.epr_get_stored_energy(**self.epr_start(no_junctions))
#     210 )
#     212 # present a human-friendly output
#     213 print(f"""
#     214 energy_elec_all       = {self.energy_elec}
#     215 energy_elec_substrate = {self.energy_elec_sub}
#    (...)    219 energy_mag % of energy_elec_all  = {self.energy_mag / self.energy_elec * 100:.1f}%
#     220 """)
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:202, in EPRanalysis.epr_start(self, no_junctions)
#     198 system["junctions"] = (
#     199     {} if no_junctions else {k: dict(v) for (k, v) in s.junctions.items()}
#     200 )
#     201 system["dissipatives"] = dict(s.dissipatives)
# --> 202 self.sim.renderer.epr_start(**system)
#     203 return system
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:1800, in QAnsysRenderer.epr_start(self, junctions, dissipatives)
#    1797         self.pinfo.dissipative[k] = v
#    1799 # Class handling microwave analysis on eigenmode solutions
# -> 1800 self.epr_distributed_analysis = epr.DistributedAnalysis(self.pinfo)
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:171, in DistributedAnalysis.__init__(self, *args, **kwargs)
#     167 self._hfss_variables = Dict()
#     169 self._previously_analyzed = set()  # previously analyzed variations
# --> 171 self.update_ansys_info()
#     173 logger.info('Design "%s" info:', self.design.name)
#     174 logger.info(
#     175     "\t%-15s %d\n\t%-15s %d",
#     176     "# eigenmodes", self.n_modes, "# variations", self.n_variations,
#     177 )
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:507, in DistributedAnalysis.update_ansys_info(self)
#     504     else:
#     505         self.n_modes = 0
# --> 507 self._update_ansys_variables()
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:516, in DistributedAnalysis._update_ansys_variables(self, variations)
#     513 variations = variations or self.variations
#     514 for variation in variations:
#     515     self._hfss_variables[variation] = pd.Series(
# --> 516         self.get_variables(variation=variation)
#     517     )
#     518 return self._hfss_variables
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:542, in DistributedAnalysis.get_variables(self, variation)
#     534 def get_variables(self, variation=None):
#     535     """
#     536     Get ansys variables.
#     537
#    (...)    540             such as '0', '1', ...
#     541     """
# --> 542     lv = self._get_lv(variation)
#     543     variables = OrderedDict()
#     544     for ii in range(int(len(lv) / 2)):
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:370, in DistributedAnalysis._get_lv(self, variation)
#     368     lv = self._parse_listvariations(lv)
#     369 else:
# --> 370     lv = self._list_variations[ureg(variation)]
#     371     lv = self._parse_listvariations(lv)
#     372 return lv
#
# TypeError: tuple indices must be integers or slices, not Quantity

# %% [markdown]
# ## 3. Analyze the combined transmon + CPW resonator system
#
# ### Finite Element Eigenmode Analysis
#
# #### Setup
#
# Create a separate analysis object for the combined qbit+readout.

# %%
eig_qres = EPRanalysis(design, "hfss")

# %% [markdown]
# For the resonator analysis we look for 2 eigenmodes - one with stronger fields near the transmon, the other with stronger fields near the resonator. Therefore let's update the setup accordingly.

# %%
eig_qres.sim.setup.n_modes = 2
eig_qres.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1,
#  'n_modes': 2,
#  'max_delta_f': 0.5,
#  'max_passes': 10,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '10 nH', 'Cj': '0 fF'}}

# %% [markdown]
# #### Execute simulation and verify convergence and EM field
# Analyze the qubit+readout. Select the qubit and the readout, then finalize with open termination on the other pins.

# %%
eig_qres.sim.run(
    name="TransmonResonator",
    components=["Q1", "readout", "open_to_ground"],
    open_terminations=[("readout", "end")],
)
eig_qres.sim.plot_convergences()
# Out:
# INFO 12:44PM [connect_design]: 	Opened active design
# 	Design:    TransmonResonator_hfss [Solution type: Eigenmode]
# WARNING 12:44PM [connect_setup]: 	No design setup detected.
# WARNING 12:44PM [connect_setup]: 	Creating eigenmode default setup.
# INFO 12:44PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:44PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:44PM [analyze]: Analyzing setup Setup
# 12:46PM 07s INFO [get_f_convergence]: Saved convergences to c:\Users\DELL\chip-design\metal-flow\tutorials\4 Analysis\A. Core - EM and quantization\hfss_eig_f_convergence.csv

# %%
eig_qres.sim.save_screenshot()  # optional
# Out:
# WindowsPath('c:/Users/DELL/chip-design/metal-flow/tutorials/4 Analysis/A. Core - EM and quantization/ansys.png')

# %% [markdown]
# Display the Ansys modeler window again and plot the E-field on the chip's surface. you can select which of the two modes to visualize.

# %%
eig_qres.sim.plot_fields("main", eigenmode=1)
# Out:
# INFO 12:47PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)

# %%
eig_qres.sim.save_screenshot()
# Out:
# WindowsPath('c:/Users/DELL/chip-design/metal-flow/tutorials/4 Analysis/A. Core - EM and quantization/ansys.png')

# %% [markdown]
# ### EPR Analysis

# %% [markdown]
# Similarly to section 1, we need to pass to the renderer the names of the shapes that identify the junction (`rect` and `line`). These should be the same as in section 1, or you can look again for those in the renderer.

# %%
eig_qres.setup.junctions.jj.rect = "JJ_rect_Lj_Q1_rect_jj"
eig_qres.setup.junctions.jj.line = "JJ_Lj_Q1_rect_jj_"
eig_qres.setup
# Out:
# {'junctions': {'jj': {'Lj_variable': 'Lj',
#    'Cj_variable': 'Cj',
#    'rect': 'JJ_rect_Lj_Q1_rect_jj',
#    'line': 'JJ_Lj_Q1_rect_jj_'}},
#  'dissipatives': {'dielectrics_bulk': ['main']},
#  'cos_trunc': 8,
#  'fock_trunc': 7,
#  'sweep_variable': 'Lj'}

# %% [markdown]
# We will now run epr as a single step. On screen you will observe various information in this order:
# * stored energy = Electric and magnetic energy stored in the substrate and the system as a whole.
# * EPR analysis results for all modes/variations.
# * Spectrum analysis.
# * Hamiltonian report.

# %%
eig_qres.run_epr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 eig_qres.run_epr()
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:176, in EPRanalysis.run_epr(self, no_junctions)
#     173 # wipe data from the previous run (if any)
#     174 self.clear_data()
# --> 176 self.get_stored_energy(no_junctions)
#     177 if not no_junctions:
#     178     self.run_analysis()
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:209, in EPRanalysis.get_stored_energy(self, no_junctions)
#     206 """Calculate the energy stored in the system based on the eigenmode results."""
#     207 # execute EPR and energy extraction
#     208 self.energy_elec, self.energy_elec_sub, self.energy_mag = (
# --> 209     self.sim.renderer.epr_get_stored_energy(**self.epr_start(no_junctions))
#     210 )
#     212 # present a human-friendly output
#     213 print(f"""
#     214 energy_elec_all       = {self.energy_elec}
#     215 energy_elec_substrate = {self.energy_elec_sub}
#    (...)    219 energy_mag % of energy_elec_all  = {self.energy_mag / self.energy_elec * 100:.1f}%
#     220 """)
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:202, in EPRanalysis.epr_start(self, no_junctions)
#     198 system["junctions"] = (
#     199     {} if no_junctions else {k: dict(v) for (k, v) in s.junctions.items()}
#     200 )
#     201 system["dissipatives"] = dict(s.dissipatives)
# --> 202 self.sim.renderer.epr_start(**system)
#     203 return system
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:1800, in QAnsysRenderer.epr_start(self, junctions, dissipatives)
#    1797         self.pinfo.dissipative[k] = v
#    1799 # Class handling microwave analysis on eigenmode solutions
# -> 1800 self.epr_distributed_analysis = epr.DistributedAnalysis(self.pinfo)
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:171, in DistributedAnalysis.__init__(self, *args, **kwargs)
#     167 self._hfss_variables = Dict()
#     169 self._previously_analyzed = set()  # previously analyzed variations
# --> 171 self.update_ansys_info()
#     173 logger.info('Design "%s" info:', self.design.name)
#     174 logger.info(
#     175     "\t%-15s %d\n\t%-15s %d",
#     176     "# eigenmodes", self.n_modes, "# variations", self.n_variations,
#     177 )
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:507, in DistributedAnalysis.update_ansys_info(self)
#     504     else:
#     505         self.n_modes = 0
# --> 507 self._update_ansys_variables()
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:516, in DistributedAnalysis._update_ansys_variables(self, variations)
#     513 variations = variations or self.variations
#     514 for variation in variations:
#     515     self._hfss_variables[variation] = pd.Series(
# --> 516         self.get_variables(variation=variation)
#     517     )
#     518 return self._hfss_variables
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:542, in DistributedAnalysis.get_variables(self, variation)
#     534 def get_variables(self, variation=None):
#     535     """
#     536     Get ansys variables.
#     537
#    (...)    540             such as '0', '1', ...
#     541     """
# --> 542     lv = self._get_lv(variation)
#     543     variables = OrderedDict()
#     544     for ii in range(int(len(lv) / 2)):
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:370, in DistributedAnalysis._get_lv(self, variation)
#     368     lv = self._parse_listvariations(lv)
#     369 else:
# --> 370     lv = self._list_variations[ureg(variation)]
#     371     lv = self._parse_listvariations(lv)
#     372 return lv
#
# TypeError: tuple indices must be integers or slices, not Quantity

# %% [markdown]
# Once you are sure you are done with the qubit analysis, please explicitly release the Ansys session to allow for a smooth close of the external tool.

# %%
eig_qb.sim.close()

# %%
eig_rd.sim.close()

# %%
eig_qres.sim.close()

# %% [markdown]
# ## 4. Analyze a coupled 2-transmon system
# ### Create the design
#
# This is a different system than the one analyzed in sections 1,2,3. Therefore, let's start by deleting the design currntly in the Qiskit Metal GUI (if any).

# %%
design.delete_all_components()

# %% [markdown]
# Next, we create the `TwoTransmon` design, consisting of 2 transmons connected by a short coupler.

# %%
from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight

q1 = TransmonPocket(
    design,
    "Q1",
    options=dict(
        pad_width="425 um",
        pocket_height="650um",
        connection_pads=dict(readout=dict(loc_W=+1, loc_H=+1, pad_width="200um")),
    ),
)

q2 = TransmonPocket(
    design,
    "Q2",
    options=dict(
        pos_x="1.0 mm",
        pad_width="425 um",
        pocket_height="650um",
        connection_pads=dict(readout=dict(loc_W=-1, loc_H=+1, pad_width="200um")),
    ),
)

coupler = RouteStraight(
    design,
    "coupler",
    Dict(
        hfss_wire_bonds=True,
        pin_inputs=Dict(
            start_pin=Dict(component="Q1", pin="readout"),
            end_pin=Dict(component="Q2", pin="readout"),
        ),
    ),
)

gui.rebuild()
gui.autoscale()

# %% [markdown]
# Let's observe the current table describing the junctions in the qiskit metal design

# %%
design.qgeometry.tables["junction"]
# Out:
#   component     name                        geometry  layer  subtract  helper  \
# 0         4  rect_jj  LINESTRING (0 -0.015, 0 0.015)      1     False   False
# 1         5  rect_jj  LINESTRING (1 -0.015, 1 0.015)      1     False   False
#
#    chip  width hfss_inductance  hfss_capacitance  ...  hfss_mesh_kw_jj  \
# 0  main   0.02            10nH                 0  ...         0.000007
# 1  main   0.02            10nH                 0  ...         0.000007
#
#    q3d_inductance q3d_capacitance  q3d_resistance  q3d_mesh_kw_jj  \
# 0            10nH               0               0        0.000007
# 1            10nH               0               0        0.000007
#
#        gds_cell_name aedt_q3d_inductance  aedt_q3d_capacitance  \
# 0  my_other_junction        1.000000e-08                     0
# 1  my_other_junction        1.000000e-08                     0
#
#    aedt_hfss_inductance  aedt_hfss_capacitance
# 0          1.000000e-08                      0
# 1          1.000000e-08                      0
#
# [2 rows x 21 columns]

# %% [markdown]
# You can observe in the table above that every junction has been assigned a default inductance, capacitance and resistance values, based on the originating component class `default_options`. In this example we intend to replace those values with a variable name, which will later be set directly in the renderer. Therefore, let's proceed with updating these values in the qubit instances, and then propagate the update to the table with a `rebuild()`.
# After executing the cell below, you can observe the change by re-executing the cell above.

# %%
# TODO: fold this inside either an analysis class method, or inside the analysis class setup

qcomps = design.components  # short handle (alias)
qcomps["Q1"].options["hfss_inductance"] = "Lj1"
qcomps["Q1"].options["hfss_capacitance"] = "Cj1"
qcomps["Q2"].options["hfss_inductance"] = "Lj2"
qcomps["Q2"].options["hfss_capacitance"] = "Cj2"
gui.rebuild()  # line needed to propagate the updates from the qubit instance into the junction design table
gui.autoscale()

# %% [markdown]
# ### Finite Element Eigenmode Analysis
#
# #### Setup
#
# Let's start the analysis by creating the appropriate analysis object.

# %%
from qiskit_metal.analyses.quantization import EPRanalysis

eig_2qb = EPRanalysis(design, "hfss")

# %% [markdown]
# Now let us update the setup of this analysis to reflect what we plan to do:
# * define the variables that we have assigned to the inductance and capacitance of the junctions;
# * increase accuracy of the convergence;
# * observe the eigenmode corresponding to both qubits.

# %%
eig_2qb.sim.setup.max_passes = 15
eig_2qb.sim.setup.max_delta_f = 0.05
eig_2qb.sim.setup.n_modes = 2
eig_2qb.sim.setup.vars = Dict(Lj1="13 nH", Cj1="0 fF", Lj2="9 nH", Cj2="0 fF")
eig_2qb.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1,
#  'n_modes': 2,
#  'max_delta_f': 0.05,
#  'max_passes': 15,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj1': '13 nH', 'Cj1': '0 fF', 'Lj2': '9 nH', 'Cj2': '0 fF'}}

# %% [markdown]
# By default, the analysis will be done on all components that we will list in the `run_sim()` method, but the analysis needs to know how much of the ground plane around the qubit to consider. One could use the declared chip dimension by passing the parameter `bux_plus_buffer = False` to the `run_sim()` method. However, its default (when said parameter is omitted) is to consider the ground plane to be as big as the minimum enclosing rectangle plus a set buffer. The default buffer value is `200um`, while in the cell below we will increase as an example that buffer to `500um`.

# %%
# TODO: fold this inside either an analysis class method, or inside the analysis class setup

eig_2qb.sim.renderer.options["x_buffer_width_mm"] = 0.5
eig_2qb.sim.renderer.options["y_buffer_width_mm"] = 0.5
eig_2qb.sim.renderer.options
# Out:
# {'Lj': '10nH',
#  'Cj': 0,
#  '_Rj': 0,
#  'max_mesh_length_jj': '7um',
#  'max_mesh_length_port': '7um',
#  'project_path': None,
#  'project_name': None,
#  'design_name': None,
#  'x_buffer_width_mm': 0.5,
#  'y_buffer_width_mm': 0.5,
#  'wb_threshold': '400um',
#  'wb_offset': '0um',
#  'wb_size': 5,
#  'plot_ansys_fields_options': {'name': 'NAME:Mag_E1',
#   'UserSpecifyName': '0',
#   'UserSpecifyFolder': '0',
#   'QuantityName': 'Mag_E',
#   'PlotFolder': 'E Field',
#   'StreamlinePlot': 'False',
#   'AdjacentSidePlot': 'False',
#   'FullModelPlot': 'False',
#   'IntrinsicVar': "Phase='0deg'",
#   'PlotGeomInfo_0': '1',
#   'PlotGeomInfo_1': 'Surface',
#   'PlotGeomInfo_2': 'FacesList',
#   'PlotGeomInfo_3': '1'}}

# %% [markdown]
# Let's finally run the cap extraction simulation and observe the convergence.

# %%
eig_2qb.sim.run(name="TwoTransmons", components=["coupler", "Q1", "Q2"])
# Out:
# INFO 12:47PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 12:47PM [load_ansys_project]: 	Opened Ansys App
# INFO 12:47PM [load_ansys_project]: 	Opened Ansys Desktop v2025.1.4
# INFO 12:47PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/DELL/Documents/Ansoft/
# 	Project:   Project267
# INFO 12:47PM [connect_design]: 	Opened active design
# 	Design:    TransmonResonator_hfss [Solution type: Eigenmode]
# INFO 12:47PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:47PM [connect]: 	Connected to project "Project267" and design "TransmonResonator_hfss" 😀
#
# INFO 12:47PM [connect_design]: 	Opened active design
# 	Design:    TwoTransmons_hfss [Solution type: Eigenmode]
# WARNING 12:47PM [connect_setup]: 	No design setup detected.
# WARNING 12:47PM [connect_setup]: 	Creating eigenmode default setup.
# INFO 12:47PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:47PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 12:47PM [analyze]: Analyzing setup Setup
# 12:51PM 40s INFO [get_f_convergence]: Saved convergences to c:\Users\DELL\chip-design\metal-flow\tutorials\4 Analysis\A. Core - EM and quantization\hfss_eig_f_convergence.csv

# %%
eig_2qb.sim.plot_convergences()

# %%
eig_2qb.sim.save_screenshot()  # optional
# Out:
# WindowsPath('c:/Users/DELL/chip-design/metal-flow/tutorials/4 Analysis/A. Core - EM and quantization/ansys.png')

# %% [markdown]
# Display the Ansys modeler window again and plot the E-field on the chip's surface. Since we have analyzed 2 modes, you will need to select which mode to visualize. The default is mode 1, but the mode can inclusively be any integer between 1 and `setup.n_modes`.

# %%
eig_2qb.sim.plot_fields("main", eigenmode=2)
eig_2qb.sim.save_screenshot()
# Out:
# INFO 02:25PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# WindowsPath('c:/Users/DELL/chip-design/metal-flow/tutorials/4 Analysis/A. Core - EM and quantization/ansys.png')

# %% [markdown]
# ### EPR Analysis
# #### Setup
# Identify the non-linear (Josephson) junctions in the model. in this case there are 2 junctions, which we will refer to as `jj1` and `jj2`. Also define the dissipative reference shapes. Remove the default junction and create the two.

# %%
del eig_2qb.setup.junctions["jj"]

# %%
eig_2qb.setup.junctions.jj1 = Dict(
    rect="JJ_rect_Lj_Q1_rect_jj",
    line="JJ_Lj_Q1_rect_jj_",
    Lj_variable="Lj1",
    Cj_variable="Cj1",
)
eig_2qb.setup.junctions.jj2 = Dict(
    rect="JJ_rect_Lj_Q2_rect_jj",
    line="JJ_Lj_Q2_rect_jj_",
    Lj_variable="Lj2",
    Cj_variable="Cj2",
)
eig_2qb.setup.sweep_variable = "Lj1"
eig_2qb.setup
# Out:
# {'junctions': {'jj1': {'rect': 'JJ_rect_Lj_Q1_rect_jj',
#    'line': 'JJ_Lj_Q1_rect_jj_',
#    'Lj_variable': 'Lj1',
#    'Cj_variable': 'Cj1'},
#   'jj2': {'rect': 'JJ_rect_Lj_Q2_rect_jj',
#    'line': 'JJ_Lj_Q2_rect_jj_',
#    'Lj_variable': 'Lj2',
#    'Cj_variable': 'Cj2'}},
#  'dissipatives': {'dielectrics_bulk': ['main']},
#  'cos_trunc': 8,
#  'fock_trunc': 7,
#  'sweep_variable': 'Lj1'}

# %% [markdown]
# Find the electric and magnetic energy stored in the substrate and the system as a whole.

# %%
eig_2qb.run_epr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 eig_2qb.run_epr()
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:176, in EPRanalysis.run_epr(self, no_junctions)
#     173 # wipe data from the previous run (if any)
#     174 self.clear_data()
# --> 176 self.get_stored_energy(no_junctions)
#     177 if not no_junctions:
#     178     self.run_analysis()
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:209, in EPRanalysis.get_stored_energy(self, no_junctions)
#     206 """Calculate the energy stored in the system based on the eigenmode results."""
#     207 # execute EPR and energy extraction
#     208 self.energy_elec, self.energy_elec_sub, self.energy_mag = (
# --> 209     self.sim.renderer.epr_get_stored_energy(**self.epr_start(no_junctions))
#     210 )
#     212 # present a human-friendly output
#     213 print(f"""
#     214 energy_elec_all       = {self.energy_elec}
#     215 energy_elec_substrate = {self.energy_elec_sub}
#    (...)    219 energy_mag % of energy_elec_all  = {self.energy_mag / self.energy_elec * 100:.1f}%
#     220 """)
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\analyses\quantization\energy_participation_ratio.py:202, in EPRanalysis.epr_start(self, no_junctions)
#     198 system["junctions"] = (
#     199     {} if no_junctions else {k: dict(v) for (k, v) in s.junctions.items()}
#     200 )
#     201 system["dissipatives"] = dict(s.dissipatives)
# --> 202 self.sim.renderer.epr_start(**system)
#     203 return system
#
# File ~\chip-design\metal-flow\quantum-metal\src\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:1800, in QAnsysRenderer.epr_start(self, junctions, dissipatives)
#    1797         self.pinfo.dissipative[k] = v
#    1799 # Class handling microwave analysis on eigenmode solutions
# -> 1800 self.epr_distributed_analysis = epr.DistributedAnalysis(self.pinfo)
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:171, in DistributedAnalysis.__init__(self, *args, **kwargs)
#     167 self._hfss_variables = Dict()
#     169 self._previously_analyzed = set()  # previously analyzed variations
# --> 171 self.update_ansys_info()
#     173 logger.info('Design "%s" info:', self.design.name)
#     174 logger.info(
#     175     "\t%-15s %d\n\t%-15s %d",
#     176     "# eigenmodes", self.n_modes, "# variations", self.n_variations,
#     177 )
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:507, in DistributedAnalysis.update_ansys_info(self)
#     504     else:
#     505         self.n_modes = 0
# --> 507 self._update_ansys_variables()
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:516, in DistributedAnalysis._update_ansys_variables(self, variations)
#     513 variations = variations or self.variations
#     514 for variation in variations:
#     515     self._hfss_variables[variation] = pd.Series(
# --> 516         self.get_variables(variation=variation)
#     517     )
#     518 return self._hfss_variables
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:542, in DistributedAnalysis.get_variables(self, variation)
#     534 def get_variables(self, variation=None):
#     535     """
#     536     Get ansys variables.
#     537
#    (...)    540             such as '0', '1', ...
#     541     """
# --> 542     lv = self._get_lv(variation)
#     543     variables = OrderedDict()
#     544     for ii in range(int(len(lv) / 2)):
#
# File c:\Users\DELL\chip-design\metal-flow\.venv\Lib\site-packages\pyEPR\core_distributed_analysis.py:370, in DistributedAnalysis._get_lv(self, variation)
#     368     lv = self._parse_listvariations(lv)
#     369 else:
# --> 370     lv = self._list_variations[ureg(variation)]
#     371     lv = self._parse_listvariations(lv)
#     372 return lv
#
# TypeError: tuple indices must be integers or slices, not Quantity

# %% [markdown]
# Release Ansys's session

# %%
eig_2qb.sim.close()

# %% [markdown]
# (optional) **final wrap**: Close the gui by removing the # in the line below.

# %%
# gui.main_window.close()
